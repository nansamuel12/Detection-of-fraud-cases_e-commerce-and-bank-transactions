# %% [markdown]
# # EDA - Credit Card Data (Bank Transactions)
#
# This notebook performs Exploratory Data Analysis on the Credit Card dataset.

# %%
import pandas as pd
import sys
import os

# Add src to path
sys.path.append(os.path.abspath(os.path.join('../src')))

from data_loader import load_data, basic_cleaning
from visualization import set_style, plot_class_distribution, plot_numerical_distributions

set_style()

# %% [markdown]
# ## 1. Data Loading

# %%
cc_df = load_data('../data/raw/creditcard.csv')
cc_df = basic_cleaning(cc_df)
cc_df.info()

# %% [markdown]
# ## 2. Exploratory Data Analysis

# %%
# Class Imbalance
plot_class_distribution(cc_df['Class'], title="Fraud Class Distribution (Credit Card)")

# %%
# Numerical Distributions
# V1-V28 are PCA components, let's look at Time and Amount
plot_numerical_distributions(cc_df, ['Time', 'Amount'], hue='Class')
